# %% [markdown]
# # scripts/generate_feature_dataframe.py

# %%
import joblib
import numpy as np
import pandas as pd
from tqdm.autonotebook import tqdm

# %%
def vars_values_for_a_line(holder, i, variables, len_sub_variables):
    if not holder[i]["deliverable"]:
        values = [np.nan] * len_sub_variables
        return values
    values = []
    for var in variables:
        values.extend(holder[i]["deliverable"][var][0].tolist())
    return values


def generate_deliverable_variables(holder):
    variables = list(holder[0]["deliverable"].keys())
    sub_variables = []
    for var in variables:
        sub_variables.extend(
            [f"{var}_{j}" for j in range(holder[0]["deliverable"][var].shape[-1])]
        )
    return variables, sub_variables


def generate_vars_df(holder):
    variables, sub_variables = generate_deliverable_variables(holder)
    var_values = []
    for i in tqdm(holder):
        values = vars_values_for_a_line(holder, i, variables, len(sub_variables))
        var_values.append(values)
    var_values = np.array(var_values)
    return pd.DataFrame(var_values, columns=sub_variables)


def generate_index_df(holder):
    unique_id = np.array([holder[i]["unique_id"] for i in holder]).reshape(-1, 1)
    primary_key = np.array([holder[i]["primary_key"] for i in holder])
    index = [
        "unique_id",
        "attack_name",
        "attack_toolchain",
        "attack_id",
        "scenario",
        "target_model",
        "target_model_dataset",
        "attack_id_bis",
    ]
    df_values = np.hstack([unique_id, primary_key])
    index_df = pd.DataFrame(df_values, columns=index)
    return index_df


def get_df_from_holder(holder):
    index_df = generate_index_df(holder)
    var_df = generate_vars_df(holder)
    final_df = pd.concat([index_df, var_df], axis=1)

    return final_df

# %%
holder = joblib.load(
    "../data_tcab/reprs/samplewise/fr+small_distilcamembert_allocine_ALL.joblib"
)

# %%
df = get_df_from_holder(holder)
# Out:
#   0%|          | 0/28913 [00:00<?, ?it/s]

# %%
canine_holder = joblib.load(
    r"../data_tcab\reprs\samplewise\fr+canine_distilcamembert_allocine_ALL_TP.joblib"
)

# %%
canine_df = get_df_from_holder(canine_holder)
# Out:
#   0%|          | 0/28913 [00:00<?, ?it/s]

# %%
canine_df = canine_df.set_index("unique_id")
canine_df = canine_df[canine_df.columns[canine_df.columns.str.startswith("tp")]]
canine_df.columns = [
    "canine_" + col for col in canine_df.columns[canine_df.columns.str.startswith("tp")]
]

# %%
df_with_canine = pd.merge(
    df, canine_df, left_on="unique_id", right_index=True, how="left"
)

# %%
df_with_canine["canine_tp_num_lowercase_after_punctuation_0"].isna().sum()
# Out:
# 1

# %%
df.to_pickle("../data_tcab/whole_feature_dataset.pickle")

# %%
df_with_canine.to_pickle("../data_tcab/whole_feature_dataset_with_canine.pickle")

# %%
df
# Out:
#                                      unique_id attack_name attack_toolchain  \
# 0      166201344496741554700726886801777804838       clean             none
# 1      209587608850316071685484207225827196902       clean             none
# 2        2212791274013000891344938268017941685       clean             none
# 3      117702114055223057842675184853669073226       clean             none
# 4      214365221041725899015601930476588894361       clean             none
# ...                                        ...         ...              ...
# 28908  178870397565426230261279084696916458885  textfooler       textattack
# 28909  297009786167894233980202763751134804379  textfooler       textattack
# 28910  328367081408891296663448180370005165130  textfooler       textattack
# 28911   48183569796911915420194851451235655871  textfooler       textattack
# 28912   65730871458346986081585985834432164142  textfooler       textattack
#
#       attack_id   scenario     target_model target_model_dataset  \
# 0             0  sentiment  distilcamembert             allocine
# 1             1  sentiment  distilcamembert             allocine
# 2             2  sentiment  distilcamembert             allocine
# 3             3  sentiment  distilcamembert             allocine
# 4             4  sentiment  distilcamembert             allocine
# ...         ...        ...              ...                  ...
# 28908      2063  sentiment  distilcamembert             allocine
# 28909      2064  sentiment  distilcamembert             allocine
# 28910      2065  sentiment  distilcamembert             allocine
# 28911      2066  sentiment  distilcamembert             allocine
# 28912      2067  sentiment  distilcamembert             allocine
#
#       attack_id_bis  tp_avg_word_length_0  tp_avg_word_length_1  ...  \
# 0                 0              6.000000              6.500000  ...
# 1                 1              4.333333              6.888889  ...
# 2                 2              4.333333              2.888889  ...
# 3                 3              3.857143              6.408163  ...
# 4                 4              4.000000              6.000000  ...
# ...             ...                   ...                   ...  ...
# 28908          2063              4.500000              6.704545  ...
# 28909          2064              4.647059              9.561707  ...
# 28910          2065              5.720930              9.038399  ...
# 28911          2066              4.187500              3.152344  ...
# 28912          2067              4.800000              3.560000  ...
#
#        tm_gradient_2073  tm_gradient_2074  tm_gradient_2075  tm_posterior_0  \
# 0              0.459151     -2.980232e-08      1.998116e+00        0.000471
# 1              0.076857      1.490116e-08      2.879451e-01        0.620563
# 2              0.302853     -2.980232e-08      1.975316e+00        0.006190
# 3              0.000131      3.195601e-08      1.502552e-07        0.999726
# 4              0.000149     -1.001172e-08      2.015418e-07        0.999683
# ...                 ...               ...               ...             ...
# 28908          0.091875      1.490116e-08      4.392960e-01        0.531334
# 28909          0.077698     -1.490116e-08      2.199249e-01        0.668394
# 28910          0.085552     -5.960464e-08      3.524275e-01        0.580222
# 28911          0.109585     -2.980232e-08      5.981153e-01        0.453138
# 28912          0.202058      0.000000e+00      1.754216e+00        0.063460
#
#        tm_posterior_1  tm_saliency_0  tm_saliency_1  tm_saliency_2  \
# 0            0.999529       0.018868       0.000557       0.002822
# 1            0.379437       0.010417       0.000237       0.001063
# 2            0.993810       0.066667       0.006728       0.024232
# 3            0.000274       0.024390       0.000841       0.007422
# 4            0.000317       0.034483       0.000998       0.012688
# ...               ...            ...            ...            ...
# 28908        0.468666       0.007634       0.000100       0.002760
# 28909        0.331606       0.003300       0.000016       0.000643
# 28910        0.419778       0.004082       0.000038       0.000741
# 28911        0.546862       0.011765       0.000153       0.003648
# 28912        0.936540       0.017241       0.001124       0.003176
#
#        tm_saliency_3  tm_saliency_4
# 0           0.010654       0.022047
# 1           0.004222       0.012058
# 2           0.039765       0.062128
# 3           0.012783       0.025159
# 4           0.023816       0.053114
# ...              ...            ...
# 28908       0.004835       0.008063
# 28909       0.001924       0.004340
# 28910       0.002107       0.004601
# 28911       0.007564       0.016643
# 28912       0.007074       0.013906
#
# [28913 rows x 4547 columns]
